# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprintpp import pprint as pp

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Generate initial data
cities_df = pd.read_csv('../output_data/cities.csv', index_col = False).dropna()
cities_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Conway  35.0887  -92.4421     55.38        81          90
# 1  São João da Barra -21.6403  -41.0511     70.56        87         100
# 2           Khatanga  71.9667  102.5000      5.86        85         100
# 3            Mataura -46.1927  168.8643     74.50        38          57
# 4            Rikitea -23.1203 -134.9692     75.54        81         100
#
#    Wind Speed Country        Date
# 0        5.99      US  1635557217
# 1       16.26      BR  1635557407
# 2        8.03      RU  1635557209
# 3        5.01      NZ  1635557409
# 4       15.68      PF  1635557409

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmap
gmaps.configure(api_key = g_key)

# %%
locations = cities_df[["Lat", "Lng"]]
weight = cities_df["Humidity"]

# %%
#Pulling in Gmaps/generate heat map

fig = gmaps.figure(center=(22.0, -1.0), zoom_level = 2)
heat_layer = gmaps.heatmap_layer(locations, weights = weight, 
                                 dissipating = False, max_intensity = np.max(weight),
                                 point_radius = 4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Generate initial dataframe
cities_new_df = cities_df.dropna()
cities_new_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Conway  35.0887  -92.4421     55.38        81          90
# 1  São João da Barra -21.6403  -41.0511     70.56        87         100
# 2           Khatanga  71.9667  102.5000      5.86        85         100
# 3            Mataura -46.1927  168.8643     74.50        38          57
# 4            Rikitea -23.1203 -134.9692     75.54        81         100
#
#    Wind Speed Country        Date
# 0        5.99      US  1635557217
# 1       16.26      BR  1635557407
# 2        8.03      RU  1635557209
# 3        5.01      NZ  1635557409
# 4       15.68      PF  1635557409

# %%
filtered_cities = cities_new_df.loc[(cities_new_df["Max Temp"] <= 80) & 
                                    (cities_new_df["Max Temp"] >= 70) & 
                                    (cities_new_df["Wind Speed"] < 10) &  
                                    (cities_new_df["Cloudiness"] == 0)]
                                
filtered_cities.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 25                Coalinga  36.1397 -120.3602     79.34        64           0
# 34            San Patricio  28.0170  -97.5169     72.84        27           0
# 49                 Salalah  17.0151   54.0924     77.09        61           0
# 59          Puerto Peñasco  31.3167 -113.5333     74.91        73           0
# 60  Santa Cruz de Tenerife  28.4682  -16.2546     71.69        79           0
#
#     Wind Speed Country        Date
# 25        2.93      US  1635557418
# 34        7.76      US  1635557309
# 49        5.75      OM  1635557434
# 59        6.11      MX  1635557438
# 60        1.01      ES  1635557439

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(filtered_cities)
hotel_df["Hotel Name"] = ""

# %%
#Using API/JSON data to populate hotel information

target_search = "hotels"

target_radius = 5000
target_type = "Business"

params = {
    "keyword": target_search,
    "radius":target_radius,
    "type":target_type,
    "key" : g_key
}
    
for index, row in hotel_df.iterrows():

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    
    
    hotel_info = requests.get(base_url, params=params)
    hotel_info = hotel_info.json()
    
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_info["results"][0]["name"]
        hotel_df.loc[index, "Hotel Address"] = hotel_info["results"][0]["vicinity"]
        hotel_df.loc[index, "Hotel Rating"] = hotel_info["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

pp(hotel_info)
# Out:
# {
#     'html_attributions': [],
#     'next_page_token': 'Aap_uEARb-vHM0Z683MAYb0N9_4Ik7o85ZZBxOWTeR1PwreQ0gaeiXfl5-M8vyrWSPP4eZtgM3M2V9pSwQiLhESy6TKlV9XGTePLTk8H1zM3Cmt1Pn8Z1B3ZbfySZ9mqSq6x2VVx7eDdBB635b4gk2A3z3s6yquXXt34shXey_1fujLzWIodcx0hM_LFAKDwDoMVd71Ebvh9ovwjBxMrOOWEucTLW1cTHtRrqSBiYsK1Xs39i3ki2tV5zt48ALJPTrWtktVcrpJ_LIKVzNTUYm0VgJeR4POjltJikCGucLH18D8JwPFdBnCgxGcptZvMU1u7d07CE4YkCLDe8h74ieBCbI5RGswBlKetPdtk_GdTbDEhO4phmN1R1cDExYcghmP8ZsCwm8xIOYAO34JRx7_d4y_zJfSb8j7Wo-2ZfD_AcWhHNJXp6QCybSwepZjdfBg4hKIx',
#     'results': [
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2681027, 'lng': 32.316558},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26936052989272,
#                         'lng': 32.31806997989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26666087010728,
#                         'lng': 32.31537032010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'فندق رستا بورسعيد Resta Port Said Hotel',
#             'opening_hours': {'open_now': True},
#             'photos': [
#                 {
#                     'height': 745,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/113170331155837482834">ريستا</a>',
#                     ],
#                     'photo_reference': 'Aap_uED5qoXlrewQWsQPIe8XEhV_8DozfQX6Li10L9Bl-FuzVBFIkpdRLC-RwZYra71wY4BglV8vQybjgmdoebtqNE7xE1MuQfwksHU8QyEBNWkXvQgySCNRkSwA0275mKgNsD55KZYZZlQE4PgINTPKKYMZerGTh6LXebgrG9Rxt1Bqovux',
#                     'width': 1324,
#                 },
#             ],
#             'place_id': 'ChIJf_1mn9Kd-RQRCVybo6Y9Vzo',
#             'plus_code': {
#                 'compound_code': '7898+6J El Sharq, Egypt',
#                 'global_code': '8G3J7898+6J',
#             },
#             'rating': 4.2,
#             'reference': 'ChIJf_1mn9Kd-RQRCVybo6Y9Vzo',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 1719,
#             'vicinity': 'Shokri Al Kowatli, El Sharq',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2709291, 'lng': 32.3005143},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27234042989273,
#                         'lng': 32.30187122989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26964077010728,
#                         'lng': 32.29917157010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Grand Hotel Port Said',
#             'opening_hours': {'open_now': True},
#             'photos': [
#                 {
#                     'height': 719,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/108259513027499226814">A Google User</a>',
#                     ],
#                     'photo_reference': 'Aap_uEBZ6hj6PKgwULzZQ9C7spzSVgClToUHJIzV6oBXnRLPzTcTvPpjfH1QoNAhNWSOz3bVJzEp9Ut5c_-x--lpAZoE0vlQze2EoI_wdrUx_JvJfeblCy44OubD2Nk_G8rCy_P1ZzbMlFjdAOPigNtHJv1B3nv73SCsSqri0T6YVBoon4wW',
#                     'width': 1280,
#                 },
#             ],
#             'place_id': 'ChIJ5VEVniOd-RQRu7jYpQuCtm8',
#             'plus_code': {
#                 'compound_code': '78C2+96 Qism El-Arab, Egypt',
#                 'global_code': '8G3J78C2+96',
#             },
#             'rating': 4.2,
#             'reference': 'ChIJ5VEVniOd-RQRu7jYpQuCtm8',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 111,
#             'vicinity': 'Port Said, Atef El-Sadat Street Madînet, Portsaid',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2716389, 'lng': 32.2950022},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27304202989272,
#                         'lng': 32.29637067989272,
#                     },
#                     'southwest': {
#                         'lat': 31.27034237010728,
#                         'lng': 32.29367102010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Jewel Port Said Hotel',
#             'photos': [
#                 {
#                     'height': 2976,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/110373944689070096381">emono khallno</a>',
#                     ],
#                     'photo_reference': 'Aap_uEAfMMhBou6gEqjZ1E0V_7DYmQ9DnhbKyTAaQgcmgs2N6vCU5vDoK34II3qiaG1wP4EnDtT4jeGRRipzuui4h70hDsz_eA5aO5xRpq4SUcNcm47cuFT9II_q9OXtPTuSIakfwhttkEdx66kYG4h7ZCuFSTWdwa6bRTDl-kSlG_NwYnRT',
#                     'width': 3968,
#                 },
#             ],
#             'place_id': 'ChIJI502SGKc-RQRbACmotZuRVo',
#             'plus_code': {
#                 'compound_code': '77CW+M2 El Manakh, Egypt',
#                 'global_code': '8G3J77CW+M2',
#             },
#             'rating': 3.8,
#             'reference': 'ChIJI502SGKc-RQRbACmotZuRVo',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 59,
#             'vicinity': '23 July Street, Tarh El Bahr, Road',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.270749, 'lng': 32.307802},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27205407989272,
#                         'lng': 32.30914812989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26935442010728,
#                         'lng': 32.30644847010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Aracan Hotel',
#             'photos': [
#                 {
#                     'height': 2352,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/117676715787534933716">Prabakar Kanthasamy</a>',
#                     ],
#                     'photo_reference': 'Aap_uECA_GQeb_GFXNmRdN7JSBqFoJoTn5Fv_tt2n2K0zKiDKAgMIvcXh_41ri5shN7rtm9ib7G3jYJGKPt0efshlCE3RV8f5RgXbOXWNLoM6EQrwevLLN0tIWItyFnvHuB-ewTXtd4oEQYTLcv0ERfu5RF9Z04OeMmTZD_WD9D6DATDNU_v',
#                     'width': 4160,
#                 },
#             ],
#             'place_id': 'ChIJ8Q1ehQCd-RQRp3V6jIEEUNI',
#             'plus_code': {
#                 'compound_code': '78C5+74 El Sharq, Egypt',
#                 'global_code': '8G3J78C5+74',
#             },
#             'rating': 3.9,
#             'reference': 'ChIJ8Q1ehQCd-RQRp3V6jIEEUNI',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 1379,
#             'vicinity': 'ش Tarh Al Bahr, حى الشرق، El Sharq',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2715979, 'lng': 32.2948215},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27304227989272,
#                         'lng': 32.29621002989272,
#                     },
#                     'southwest': {
#                         'lat': 31.27034262010728,
#                         'lng': 32.29351037010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Armed Forces Club & Hotel (Jewel hotel)',
#             'photos': [
#                 {
#                     'height': 3628,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/114353470313077773697">Hossam ELTABEY</a>',
#                     ],
#                     'photo_reference': 'Aap_uEAuT7X0HDXuJQYqNfFIOOo3u3F2GRiFoHm8UTcSfonCUDajCvs4XcxjX-3HIVwqMLKN49EVdx41KIGdzQoW8gtx4hpp2lF2wafgqeV1sf2kC2cGE7o5-GcFw4Q7d0EqkmTgeXqN0zw87S5ZMB5QpImlMAArTstAHy5PpyTVUBHuls3u',
#                     'width': 8336,
#                 },
#             ],
#             'place_id': 'ChIJeU2cplic-RQRSPK29XNhKCs',
#             'plus_code': {
#                 'compound_code': '77CV+JW Port Fouad City, Egypt',
#                 'global_code': '8G3J77CV+JW',
#             },
#             'rating': 3.9,
#             'reference': 'ChIJeU2cplic-RQRSPK29XNhKCs',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 583,
#             'vicinity': 'El-Shaheed Atef El-Sadat, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.271035, 'lng': 32.3111888},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27233472989272,
#                         'lng': 32.31250522989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26963507010728,
#                         'lng': 32.30980557010727,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Noras Beach Hotel',
#             'opening_hours': {'open_now': True},
#             'photos': [
#                 {
#                     'height': 463,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/102868179356171438441">A Google User</a>',
#                     ],
#                     'photo_reference': 'Aap_uEA1v-LrL3tPWQOYWH8A4CxPoy1tLtQdM4ra7xqB1KsBrPco8VET9iBTqSiwdpvfAgG5S641ADJCqu4jAs4gq-KpoNrc7PXeZWYP3BOqZXUi5zoFs7EuGStN-KheSiuR5f4cbKFEVpzGBtPEp8Q236SWTd7fQzLEDKILcUu7SQRwtRXm',
#                     'width': 720,
#                 },
#             ],
#             'place_id': 'ChIJp1VtK_6c-RQRiVfcU9jSyBM',
#             'plus_code': {
#                 'compound_code': '78C6+CF El Sharq, Egypt',
#                 'global_code': '8G3J78C6+CF',
#             },
#             'rating': 4.1,
#             'reference': 'ChIJp1VtK_6c-RQRiVfcU9jSyBM',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 224,
#             'vicinity': 'Tarh Al Bahr, El Sharq',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2628555, 'lng': 32.3103474},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26415707989272,
#                         'lng': 32.31178992989273,
#                     },
#                     'southwest': {
#                         'lat': 31.26145742010727,
#                         'lng': 32.30909027010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'De La Poste Hotel',
#             'opening_hours': {'open_now': True},
#             'photos': [
#                 {
#                     'height': 768,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/107770440096684310689">A Google User</a>',
#                     ],
#                     'photo_reference': 'Aap_uECwjfUWnjwPDf6c1eNebPfWIeaRm8tR3KE3Exn7LBrV-r3IKHPJyNE29xiXVigtiyx6PoWvRpEKMWGacFrTrBdRAvrOU2-J2HF86VxsuEeCs8GJYU4l1Xhk2XzVBJ0737SGCz3PiDWnh5LPANJiGZ2iSAKzdc_Fz3t-gFLduamuCq0n',
#                     'width': 1200,
#                 },
#             ],
#             'place_id': 'ChIJRwgEq1Sc-RQRkr3d8uoUmsc',
#             'plus_code': {
#                 'compound_code': '7876+44 Port Fouad City, Egypt',
#                 'global_code': '8G3J7876+44',
#             },
#             'rating': 3.3,
#             'reference': 'ChIJRwgEq1Sc-RQRkr3d8uoUmsc',
#             'scope': 'GOOGLE',
#             'types': [
#                 'bakery',
#                 'cafe',
#                 'lodging',
#                 'bar',
#                 'restaurant',
#                 'food',
#                 'point_of_interest',
#                 'store',
#                 'establishment',
#             ],
#             'user_ratings_total': 399,
#             'vicinity': 'El-Gomhoreya, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2710892, 'lng': 32.3151713},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27238267989272,
#                         'lng': 32.31648277989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26968302010728,
#                         'lng': 32.31378312010727,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Port Said Misr Travel Hotel',
#             'photos': [
#                 {
#                     'height': 1908,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/109003141584980187960">mohamed gomaa</a>',
#                     ],
#                     'photo_reference': 'Aap_uEAzjC8rRCVKwe7PzB0KfRr0fpXIE_NPICmf9yEg7rlqDawAeU0pGB_7ifDW7n9YYH-k2LmD4RhiqNHVlJ0GWw2wsS6HdHcucK3IoSRBaG6lkg3qtFmvwuAz-mmlsUZBMopoFt-c1stNszXlrkMys8GHkEDb7X3lkSjC8hA8TEHA9Gby',
#                     'width': 4032,
#                 },
#             ],
#             'place_id': 'ChIJLQLPQAGd-RQR2oe5rTUxfQ0',
#             'plus_code': {
#                 'compound_code': '78C8+C3 Port Fouad City, Egypt',
#                 'global_code': '8G3J78C8+C3',
#             },
#             'rating': 4.1,
#             'reference': 'ChIJLQLPQAGd-RQR2oe5rTUxfQ0',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 2048,
#             'vicinity': 'Tarh Al Bahr, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2677954, 'lng': 32.3145287},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26917867989272,
#                         'lng': 32.31582127989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26647902010727,
#                         'lng': 32.31312162010727,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Panorama Port Said Hotel',
#             'photos': [
#                 {
#                     'height': 3024,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/100961422036321332808">Tamer Mohammad</a>',
#                     ],
#                     'photo_reference': 'Aap_uECfsnnhl_rL_THsdw4AXqew4Xmaebd0G-ZTba5L3tr_gs9QCEdFXdNghBdJqd68coo01Yf-DXGB-n5rMRktE8ONcWTEHWRIQYTpxZGn2KqjqXhaKsmHtLvnQVIDEFFcQyo06_gTe-mjg9VlgKRlYVt3v_UtxHCUsyJ3ebmW0H15CO5i',
#                     'width': 4032,
#                 },
#             ],
#             'place_id': 'ChIJ3bDhJwGd-RQRUV7qmXheQVM',
#             'plus_code': {
#                 'compound_code': '7897+4R Port Fouad City, Egypt',
#                 'global_code': '8G3J7897+4R',
#             },
#             'rating': 3.5,
#             'reference': 'ChIJ3bDhJwGd-RQRUV7qmXheQVM',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 982,
#             'vicinity': 'El-Gomhoreya, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2727646, 'lng': 32.2907027},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27404132989273,
#                         'lng': 32.29204102989272,
#                     },
#                     'southwest': {
#                         'lat': 31.27134167010728,
#                         'lng': 32.28934137010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Palma Hotel Port Said',
#             'photos': [
#                 {
#                     'height': 3000,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/103230391246383473324">Heba Abo al-soud</a>',
#                     ],
#                     'photo_reference': 'Aap_uEDt-Cd5qs8qSPJpHUXl0w9urCA55xj2q-c0rDpEqcX_ExNS-CChAlEikYJqnIdvh0kD7iWs1T1miEDihlxNBVRkc641pnGmbVRRlKkg396gEEYk66n4fxUzlSoorTSQ-IuV32EO2y8U0d58VdCL3MC65eQoKwO6NM8O6phReIRkt1vj',
#                     'width': 4000,
#                 },
#             ],
#             'place_id': 'ChIJn-PrJKud-RQR6GttV31B8Js',
#             'plus_code': {
#                 'compound_code': '77FR+47 Port Fouad City, Egypt',
#                 'global_code': '8G3J77FR+47',
#             },
#             'rating': 4.6,
#             'reference': 'ChIJn-PrJKud-RQR6GttV31B8Js',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 9,
#             'vicinity': 'El-Shaheed Atef El-Sadat, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2652893, 'lng': 32.3018661},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26662697989272,
#                         'lng': 32.30321087989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26392732010728,
#                         'lng': 32.30051122010727,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Porto Said Hotel',
#             'photos': [
#                 {
#                     'height': 1868,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/114787607392296888972">Mohamed Roshdi</a>',
#                     ],
#                     'photo_reference': 'Aap_uEDXd0ZZm4cDjGPBJsneaGA-d66HALPUMO1umAUXjhiMKZnRVHeU-VJiy_FyIftBM-Cd7y_xHjcse7pmDes_GnU80Vb5r0YrHJ4Xmj--0M3V1eZqnqCn9EzK2ocNRv86Q0G6IG_G1YwVQoKBqL2wONV3ik9eaMRaWIpz-t79OGfh32SU',
#                     'width': 4000,
#                 },
#             ],
#             'place_id': 'ChIJodRzLu6d-RQRCUoHOGqzUek',
#             'plus_code': {
#                 'compound_code': '7882+4P El Sharq, Egypt',
#                 'global_code': '8G3J7882+4P',
#             },
#             'rating': 4.3,
#             'reference': 'ChIJodRzLu6d-RQRCUoHOGqzUek',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 52,
#             'vicinity': '23km, Road',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2601842, 'lng': 32.3075353},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26153127989272,
#                         'lng': 32.30889092989273,
#                     },
#                     'southwest': {
#                         'lat': 31.25883162010727,
#                         'lng': 32.30619127010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'فندق يوتوبيا بورسعيد - Utopia Port Said Hotel',
#             'photos': [
#                 {
#                     'height': 2976,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/117570810739492346228">Leka&#39;a</a>',
#                     ],
#                     'photo_reference': 'Aap_uEDG8zve5Me_XBrmOcdbrSA9t8BA8iANtQjPVQ_8gKTc4MxvstCSTDD5zZKYF_6W9RbryTMG3tnTNBq78PwjmUPy_N0s7Mkh3-1sxz30aIXkbuw6kQzHxu9tvc95_C9HmdRCbyvslS11h1S1i5vY3MkDr-wihb2flM3SGxchlkTOeq34',
#                     'width': 3968,
#                 },
#             ],
#             'place_id': 'ChIJjVtmfZyd-RQRTr4iXlox0kg',
#             'plus_code': {
#                 'compound_code': '7865+32 El Sharq, Egypt',
#                 'global_code': '8G3J7865+32',
#             },
#             'rating': 3.8,
#             'reference': 'ChIJjVtmfZyd-RQRTr4iXlox0kg',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 215,
#             'vicinity': 'ميدان المنشية - شارع الجيش وأحمد شوقي - بجوار عمر افندي بورسعيد',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2628607, 'lng': 32.3106957},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26422772989272,
#                         'lng': 32.31201277989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26152807010727,
#                         'lng': 32.30931312010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Holiday Hotel',
#             'photos': [
#                 {
#                     'height': 4618,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/113328460233372744035">Khaled Elkilany</a>',
#                     ],
#                     'photo_reference': 'Aap_uEA9_teKWRjSEz9NgjLngJZg390jucE6CGX--DBhRGT_t_LXXbMA7pCf24WD38M363VqdESYlt_Vl-j1R0oXSlrWTD3eMacFOaMA9lA8o7gDXS-maG55ijWvGtL8m1tdDGdMvzO-rrfi2ARC-IgVtkf5urkbcL9grehZdpeHYGJOgqIA',
#                     'width': 3464,
#                 },
#             ],
#             'place_id': 'ChIJRd5bqlSc-RQRVdC-YGHPKpY',
#             'plus_code': {
#                 'compound_code': '7876+47 El Sharq, Egypt',
#                 'global_code': '8G3J7876+47',
#             },
#             'rating': 3.5,
#             'reference': 'ChIJRd5bqlSc-RQRVdC-YGHPKpY',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 375,
#             'vicinity': 'El-Gomhoreya, El Sharq',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2713251, 'lng': 32.303946},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27261637989272,
#                         'lng': 32.30528892989273,
#                     },
#                     'southwest': {
#                         'lat': 31.26991672010728,
#                         'lng': 32.30258927010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Marhaba Touristic Village',
#             'photos': [
#                 {
#                     'height': 3456,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/101953953090055519918">Hassan Ghattass</a>',
#                     ],
#                     'photo_reference': 'Aap_uECPaUAcmiTvqupcJdy652dkbp4SIX0tbryCvIndQSkcF_sw53g5GsATfOen3g1aon6W2Ta7IC98S8Xda6o00AG9NNO34dCyWvRE8lT8g-bFhOdD7XJ7NTZML6PzQWrYGSPeGi7RE0wXhPw5IPc8b1IHjvCtU6VaeEIoBdE5dzUxcMqZ',
#                     'width': 3456,
#                 },
#             ],
#             'place_id': 'ChIJdVw8wfic-RQRCvsvv9Trl7Y',
#             'plus_code': {
#                 'compound_code': '78C3+GH Port Fouad City, Egypt',
#                 'global_code': '8G3J78C3+GH',
#             },
#             'rating': 4.2,
#             'reference': 'ChIJdVw8wfic-RQRCvsvv9Trl7Y',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 2902,
#             'vicinity': 'El-Shaheed Atef El-Sadat, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2596589, 'lng': 32.3037789},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26108357989272,
#                         'lng': 32.30518347989272,
#                     },
#                     'southwest': {
#                         'lat': 31.25838392010728,
#                         'lng': 32.30248382010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Hotel concord',
#             'opening_hours': {'open_now': True},
#             'photos': [
#                 {
#                     'height': 3000,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/113610662059112933597">kimo Blanco</a>',
#                     ],
#                     'photo_reference': 'Aap_uEAWjCfljsFm47gDVadroTvvNAX7drkBN1ANwTHAfQbgYenAU0D_h6Qnc60Cvm2sJqPz6DXKIpiSE4jVBNKZgKTweMneKulQThsPRKoYvApJY2NTUrAK2Vm8jH1eliaAVnPdX-5vN7JLHOhe699OArDOFLHkA204C-w_sct8yLCpszr6',
#                     'width': 4000,
#                 },
#             ],
#             'place_id': 'ChIJLw9ZGd2d-RQRcF3rTpmwkik',
#             'plus_code': {
#                 'compound_code': '7853+VG Port Fouad City, Egypt',
#                 'global_code': '8G3J7853+VG',
#             },
#             'rating': 3.4,
#             'reference': 'ChIJLw9ZGd2d-RQRcF3rTpmwkik',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 180,
#             'vicinity': 'Port Said Customs Authority, Mostafa Kamel, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2615297, 'lng': 32.3059711},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26291277989272,
#                         'lng': 32.30734687989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26021312010727,
#                         'lng': 32.30464722010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Light City Hotel',
#             'photos': [
#                 {
#                     'height': 1080,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/100663805180067850548">em bee</a>',
#                     ],
#                     'photo_reference': 'Aap_uEB_EnFU-S-h3WfALfFojFuY-eAcwMjXnJFRuYY9Q6YG7iWKE9YAnlLo56rneWeCd1LxCxZLGw0UBbgIkB39p4sYYk0LSaxXfQfo5m183G4HNYByzZXrkq8YWKva0jkLgFz_uEF0KapEJQ3EEfujjMrcD2pN3wHWB2h9JH9epbNtWzcX',
#                     'width': 1920,
#                 },
#             ],
#             'place_id': 'ChIJnauqdlGc-RQRgSqm0hqkKE0',
#             'rating': 3.4,
#             'reference': 'ChIJnauqdlGc-RQRgSqm0hqkKE0',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 453,
#             'vicinity': '7864+J99, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2631384, 'lng': 32.3113733},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26443972989272,
#                         'lng': 32.31268472989273,
#                     },
#                     'southwest': {
#                         'lat': 31.26174007010727,
#                         'lng': 32.30998507010729,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'New Regent Hotel',
#             'photos': [
#                 {
#                     'height': 4160,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/111149741898700371774">shokry mahsob</a>',
#                     ],
#                     'photo_reference': 'Aap_uEBb3AIdHURbImqyvD1wQy8Qduo1zHvDWkBKvLNIW2I_01364I5txtr1GHAP62oHjPqc-PMIiSRSShkmrCnBHN_XXXfRE1PQgLH5p9JKP0-bx23-Nw9YgjXkWmMSRgFTcQ9CMXNagVtQjL7NWNKd769bpkdoCFt89oeFzCxq_Zd7_8nK',
#                     'width': 3120,
#                 },
#             ],
#             'place_id': 'ChIJE0qusVSc-RQRQutWEmh4oSA',
#             'plus_code': {
#                 'compound_code': '7876+7G El Sharq, Egypt',
#                 'global_code': '8G3J7876+7G',
#             },
#             'rating': 2.8,
#             'reference': 'ChIJE0qusVSc-RQRQutWEmh4oSA',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 172,
#             'vicinity': 'El Sharq',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.271036, 'lng': 32.302322},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.27241722989272,
#                         'lng': 32.30367482989272,
#                     },
#                     'southwest': {
#                         'lat': 31.26971757010728,
#                         'lng': 32.30097517010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'Palma Hotel Apartments',
#             'photos': [
#                 {
#                     'height': 2184,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/114146990127806752569">A Google User</a>',
#                     ],
#                     'photo_reference': 'Aap_uEDCUJFPbwNwTovhMJpe9QWa8qa2LN_NveoKIS0X4Ym2qWGbu8XmPpwdb3zGEE1TcERFEVpZ4HDM-aj3Mtc_XVeC42P6-KU0C1iOFLIHBI6PFLtjOfT-8H7V_DpDr9b3FwOuV5ZxrJq-vCwLXO_Fi0YGI0dcUYPNN8fKTxBe-bqFAry2',
#                     'width': 4608,
#                 },
#             ],
#             'place_id': 'ChIJSxc5iPic-RQRMwBb8sKu4Xc',
#             'plus_code': {
#                 'compound_code': '78C2+CW Qism El-Arab, Egypt',
#                 'global_code': '8G3J78C2+CW',
#             },
#             'rating': 5,
#             'reference': 'ChIJSxc5iPic-RQRMwBb8sKu4Xc',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 2,
#             'vicinity': 'El-Shaheed Atef El-Sadat, Qism El-Arab',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2597147, 'lng': 32.306075},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26108377989272,
#                         'lng': 32.30739072989272,
#                     },
#                     'southwest': {
#                         'lat': 31.25838412010728,
#                         'lng': 32.30469107010728,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'فندق ريفيرا',
#             'photos': [
#                 {
#                     'height': 2250,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/110111677482705141125">Anas Osama</a>',
#                     ],
#                     'photo_reference': 'Aap_uECx75s5tUYP8OAsUyWxBDq_Fxu8ZSzg8-xP1q1iFcMRPPK83j6-sWG4RkXMCaGlwtdKZPLhSbTqF4nT7MkuKLo9hX5LrOKNYc0ZiJUnm9RuRt99ftzCpxGtCN8ysSLcrgypXPcZ3RXnV7UmVQNgTFeJgfu_ihE3xcAH1MQtCPyihPat',
#                     'width': 4000,
#                 },
#             ],
#             'place_id': 'ChIJ2ZDrEVKc-RQRcAJ0QycEQMs',
#             'plus_code': {
#                 'compound_code': '7854+VC Port Fouad City, Egypt',
#                 'global_code': '8G3J7854+VC',
#             },
#             'rating': 3.3,
#             'reference': 'ChIJ2ZDrEVKc-RQRcAJ0QycEQMs',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 342,
#             'vicinity': 'Ramsis, Port Fouad City',
#         },
#         {
#             'business_status': 'OPERATIONAL',
#             'geometry': {
#                 'location': {'lat': 31.2613428, 'lng': 32.3095039},
#                 'viewport': {
#                     'northeast': {
#                         'lat': 31.26269562989272,
#                         'lng': 32.31084872989272,
#                     },
#                     'southwest': {
#                         'lat': 31.25999597010728,
#                         'lng': 32.30814907010727,
#                     },
#                 },
#             },
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#             'icon_background_color': '#909CE1',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#             'name': 'New Continental Hotel Portsaid',
#             'photos': [
#                 {
#                     'height': 1908,
#                     'html_attributions': [
#                         '<a href="https://maps.google.com/maps/contrib/101480721678065696976">101480721678065696976</a>',
#                     ],
#                     'photo_reference': 'Aap_uECXSgqEELxrEc--5VZGc3d3VYqwTCapL5CydUtojNz2kxJgwSOW85VzmLNWXnz377nLIwR1bjlhJ8Cda4RDYtI3XgAf1TAX7rCHoE5M6RXOxASaCZCLGHIrAy7q3ptDwyfewb9R50Owuln-Mvv_679U89QFvrRc_pCCF1Aq0XeVsBJ3',
#                     'width': 4032,
#                 },
#             ],
#             'place_id': 'ChIJTUvnFlOc-RQRDRuBU_PvOxw',
#             'rating': 2.9,
#             'reference': 'ChIJTUvnFlOc-RQRDRuBU_PvOxw',
#             'scope': 'GOOGLE',
#             'types': ['lodging', 'point_of_interest', 'establishment'],
#             'user_ratings_total': 16,
#             'vicinity': '7865+GRJ, Port Fouad City',
#         },
#     ],
#     'status': 'OK',
# }

# %%
hotel_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 25                Coalinga  36.1397 -120.3602     79.34        64           0
# 34            San Patricio  28.0170  -97.5169     72.84        27           0
# 49                 Salalah  17.0151   54.0924     77.09        61           0
# 59          Puerto Peñasco  31.3167 -113.5333     74.91        73           0
# 60  Santa Cruz de Tenerife  28.4682  -16.2546     71.69        79           0
#
#     Wind Speed Country        Date                               Hotel Name  \
# 25        2.93      US  1635557418  Best Western Plus Coalinga Inn & Suites
# 34        7.76      US  1635557309           Americas Best Value Inn Sinton
# 49        5.75      OM  1635557434                    Salalah Gardens Hotel
# 59        6.11      MX  1635557438          Las Palomas Beach & Golf Resort
# 60        1.01      ES  1635557439          Iberostar Heritage Grand Mencey
#
#                                         Hotel Address  Hotel Rating
# 25                           1786 Jayne Ave, Coalinga           4.5
# 34                                 8108 US-77, Sinton           3.4
# 49                           Al Rabat Street، Salalah           4.8
# 59  Blvd. Dr. Ernesto Guevara del Campo No.150, Pl...           4.6
# 60  Calle Dr. Jose Naveiras, 38, Santa Cruz de Ten...           4.6

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations,
    info_box_content = hotel_info)


# Display figure
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
