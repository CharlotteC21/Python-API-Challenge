# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Generate initial data
cities_df = pd.read_csv('../output_data/cities.csv', index_col = False).dropna()
cities_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Conway  35.0887  -92.4421     55.38        81          90
# 1  São João da Barra -21.6403  -41.0511     70.56        87         100
# 2           Khatanga  71.9667  102.5000      5.86        85         100
# 3            Mataura -46.1927  168.8643     74.50        38          57
# 4            Rikitea -23.1203 -134.9692     75.54        81         100
#
#    Wind Speed Country        Date
# 0        5.99      US  1635557217
# 1       16.26      BR  1635557407
# 2        8.03      RU  1635557209
# 3        5.01      NZ  1635557409
# 4       15.68      PF  1635557409

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmap
gmaps.configure(api_key = g_key)

# %%
locations = cities_df[["Lat", "Lng"]]
weight = cities_df["Humidity"]

# %%
#Pulling in Gmaps/generate heat map

fig = gmaps.figure(center=(22.0, -1.0), zoom_level = 2)
heat_layer = gmaps.heatmap_layer(locations, weights = weight, 
                                 dissipating = False, max_intensity = np.max(weight),
                                 point_radius = 4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Generate initial dataframe
cities_new_df = cities_df.dropna()
cities_new_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Conway  35.0887  -92.4421     55.38        81          90
# 1  São João da Barra -21.6403  -41.0511     70.56        87         100
# 2           Khatanga  71.9667  102.5000      5.86        85         100
# 3            Mataura -46.1927  168.8643     74.50        38          57
# 4            Rikitea -23.1203 -134.9692     75.54        81         100
#
#    Wind Speed Country        Date
# 0        5.99      US  1635557217
# 1       16.26      BR  1635557407
# 2        8.03      RU  1635557209
# 3        5.01      NZ  1635557409
# 4       15.68      PF  1635557409

# %%
filtered_cities = cities_new_df.loc[(cities_new_df["Max Temp"] <= 80) & 
                                    (cities_new_df["Max Temp"] >= 70) & 
                                    (cities_new_df["Wind Speed"] < 10) &  
                                    (cities_new_df["Cloudiness"] == 0)]
                                
filtered_cities
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 25                 Coalinga  36.1397 -120.3602     79.34        64
# 34             San Patricio  28.0170  -97.5169     72.84        27
# 49                  Salalah  17.0151   54.0924     77.09        61
# 59           Puerto Peñasco  31.3167 -113.5333     74.91        73
# 60   Santa Cruz de Tenerife  28.4682  -16.2546     71.69        79
# 69              Carpinteria  34.3989 -119.5185     79.36        59
# 217               Iranshahr  27.2025   60.6848     71.85        31
# 250                  Muscat  23.6139   58.5922     73.42        53
# 355             Porto Velho  -8.7619  -63.9039     75.25        94
# 359                   Warah  27.4481   67.7978     73.71        23
# 373               Port Said  31.2565   32.2841     75.18        78
#
#      Cloudiness  Wind Speed Country        Date
# 25            0        2.93      US  1635557418
# 34            0        7.76      US  1635557309
# 49            0        5.75      OM  1635557434
# 59            0        6.11      MX  1635557438
# 60            0        1.01      ES  1635557439
# 69            0        2.75      US  1635557445
# 217           0        3.27      IR  1635557501
# 250           0        2.57      OM  1635557508
# 355           0        1.14      BR  1635557558
# 359           0        0.96      PK  1635557560
# 373           0        8.05      EG  1635557566

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(filtered_cities)
hotel_df["Hotel Name"] = ""

# %%
#Using API/JSON data to populate hotel information

target_search = "hotels"

target_radius = 5000
target_type = "Business"

params = {
    "keyword": target_search,
    "radius":target_radius,
    "type":target_type,
    "key" : g_key
}
    
for index, row in hotel_df.iterrows():

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    
    
    hotel_info = requests.get(base_url, params=params)
    hotel_info = hotel_info.json()
    
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_info["results"][0]["name"]
        hotel_df.loc[index, "Hotel Address"] = hotel_info["results"][0]["vicinity"]
        hotel_df.loc[index, "Hotel Rating"] = hotel_info["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

hotel_info
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDLPxUzH7Fd5s9wx42ilwwXh4AiwGPTbbV7Ujfsbnv1Fj7pRDHZOD40Ok1gm1H9KGGxypCLK_FlFjwK_is3VE7icQ9MctYEGNG6wlOTOS0dJwfGSquN_CXyqONyjMu9eRLGtEDh56qd-n25kmW2rQF1wrzB6VdUZgpfIyTGJmER-xk1yEtVcjpHWzRGyX-N1qqhr2kzzJTGBJbTOLsNwZ59gySxsFtLksePyBGVAkRgK_sZ8bpnHTIRrk63GsTH135P0wBocJ3RV3pjyiLGWP0akk7RkPuLTYRbak1oXjd08xzqijCXBbjEPZQAyFbrmdSsxIPSLHgciJXES0lcIc76A051VrswIcxA42YIH7kBUdivDMKbWpZTbgo-Rg4BAXkEuzxK6dMSFghKz0rhnaPw6GfCbg0tufsXlSuxYjhvNcE8_CDLrLbC0HlfRgK9FUy9',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2681027, 'lng': 32.316558},
#     'viewport': {'northeast': {'lat': 31.26936052989272,
#       'lng': 32.31806997989272},
#      'southwest': {'lat': 31.26666087010728, 'lng': 32.31537032010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'فندق رستا بورسعيد Resta Port Said Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 745,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113170331155837482834">ريستا</a>'],
#      'photo_reference': 'Aap_uEAtdfoTHRIeNAPXCcuEFpUj7pjnAnBcbEOu5gSYX9ZoHxjcw4IbaOrc9a9Ft-V4vNe9zTf5tk0PY5etKzzx3FgkqWUU-OwVHFfTUBOCP9OZMfn2Qa_VLlVEGcl61tRQ9_H0lAu84BfEgvRKO5eWuYDuF_dCy406es3EWMwagRgwGLzD',
#      'width': 1324}],
#    'place_id': 'ChIJf_1mn9Kd-RQRCVybo6Y9Vzo',
#    'plus_code': {'compound_code': '7898+6J El Sharq, Egypt',
#     'global_code': '8G3J7898+6J'},
#    'rating': 4.2,
#    'reference': 'ChIJf_1mn9Kd-RQRCVybo6Y9Vzo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1719,
#    'vicinity': 'Shokri Al Kowatli, El Sharq'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2709291, 'lng': 32.3005143},
#     'viewport': {'northeast': {'lat': 31.27234042989273,
#       'lng': 32.30187122989272},
#      'southwest': {'lat': 31.26964077010728, 'lng': 32.29917157010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Grand Hotel Port Said',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 719,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108259513027499226814">A Google User</a>'],
#      'photo_reference': 'Aap_uEBb5mu91lHSL8yl1ngaMgwAGhJyYrnCRX4pa6Zm8dtfqT-fw4IFldeA8QuUD80S519842VC2RUmkRPm-9gD8DLtaDQgTTfjFsVWrWheGATjcoaymy6Tnk-TjWRzgT7PjsDYE1vpMTRPo8l-H3RsIjTOJd4Q1eQKNsQygM3epeIDzOKY',
#      'width': 1280}],
#    'place_id': 'ChIJ5VEVniOd-RQRu7jYpQuCtm8',
#    'plus_code': {'compound_code': '78C2+96 Qism El-Arab, Egypt',
#     'global_code': '8G3J78C2+96'},
#    'rating': 4.2,
#    'reference': 'ChIJ5VEVniOd-RQRu7jYpQuCtm8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 111,
#    'vicinity': 'Port Said, Atef El-Sadat Street Madînet, Portsaid'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2716389, 'lng': 32.2950022},
#     'viewport': {'northeast': {'lat': 31.27304202989272,
#       'lng': 32.29637067989272},
#      'southwest': {'lat': 31.27034237010728, 'lng': 32.29367102010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Jewel Port Said Hotel',
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110373944689070096381">emono khallno</a>'],
#      'photo_reference': 'Aap_uEBvJee82hy1_Kt0_-Mc32m33pLVj7yh8rN4ay2VWC7HYfSdqKgeIyQq39lxoZBCtthgwb5RXUqOrXiYQbITw3NgwsQDnGKl_nZ8ER-j8iS0fGuiGedsF0bSGMctIAm881Bjxs5UWHSkS2lFAiyRR9zOMGqDJjOX1hKR_Dze7u23R5iX',
#      'width': 3968}],
#    'place_id': 'ChIJI502SGKc-RQRbACmotZuRVo',
#    'plus_code': {'compound_code': '77CW+M2 El Manakh, Egypt',
#     'global_code': '8G3J77CW+M2'},
#    'rating': 3.8,
#    'reference': 'ChIJI502SGKc-RQRbACmotZuRVo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 59,
#    'vicinity': '23 July Street, Tarh El Bahr, Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.270749, 'lng': 32.307802},
#     'viewport': {'northeast': {'lat': 31.27205407989272,
#       'lng': 32.30914812989272},
#      'southwest': {'lat': 31.26935442010728, 'lng': 32.30644847010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Aracan Hotel',
#    'photos': [{'height': 2352,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117676715787534933716">Prabakar Kanthasamy</a>'],
#      'photo_reference': 'Aap_uEDflrtMprXq4-iBI7D7ktCfnniwtnHMfc4UC1xOxh6wYdvzaTxtkOIePD8f6LzYzqKRPeE3wTELsD8TNPi48KIseaj_SzCBr15m64Id41LCyu4tuJnkI-N11s3bhLx3FiD1XjCf-UMIMXlOxJwOduVDZO2M75nDQ8kYSoal7y0cEJA7',
#      'width': 4160}],
#    'place_id': 'ChIJ8Q1ehQCd-RQRp3V6jIEEUNI',
#    'plus_code': {'compound_code': '78C5+74 El Sharq, Egypt',
#     'global_code': '8G3J78C5+74'},
#    'rating': 3.9,
#    'reference': 'ChIJ8Q1ehQCd-RQRp3V6jIEEUNI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1379,
#    'vicinity': 'ش Tarh Al Bahr, حى الشرق، El Sharq'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.271035, 'lng': 32.3111888},
#     'viewport': {'northeast': {'lat': 31.27233472989272,
#       'lng': 32.31250522989272},
#      'southwest': {'lat': 31.26963507010728, 'lng': 32.30980557010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Noras Beach Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 463,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102868179356171438441">A Google User</a>'],
#      'photo_reference': 'Aap_uECdw5VxK8C7wBtbW1M1_tnjvT_L98ig6AGrkm5QN3lSoHMlZ0rAr69krJRR0N1Xa-jObuZuCeb7AbyhpG8LPxOK3F_lD1czq9GxrU_n_aohNpCI-webHW7iAXIOgZLxpr61HECHRrr8tfuLpAAnGLy-9vOdGxim9GrabKF6ZP7JNCOG',
#      'width': 720}],
#    'place_id': 'ChIJp1VtK_6c-RQRiVfcU9jSyBM',
#    'plus_code': {'compound_code': '78C6+CF El Sharq, Egypt',
#     'global_code': '8G3J78C6+CF'},
#    'rating': 4.1,
#    'reference': 'ChIJp1VtK_6c-RQRiVfcU9jSyBM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 224,
#    'vicinity': 'Tarh Al Bahr, El Sharq'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2715979, 'lng': 32.2948215},
#     'viewport': {'northeast': {'lat': 31.27304227989272,
#       'lng': 32.29621002989272},
#      'southwest': {'lat': 31.27034262010728, 'lng': 32.29351037010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Armed Forces Club & Hotel (Jewel hotel)',
#    'photos': [{'height': 3628,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114353470313077773697">Hossam ELTABEY</a>'],
#      'photo_reference': 'Aap_uEB-h0PiL9GmlJzlvanrWwsEwKWgZ_90HeBCplD41pnIbtcOzsTyiYEabVp6ZuRq9OVrT4MLFKgqRwzoaEqJoOwLqRoP8K-5TPAIX1vtP_zLlAPSlkEaxkwyUyMYNvmAMb5gbOiypupxjmsu_OdOYFOwbk7tW3t6nArpXkq1V6zQegNZ',
#      'width': 8336}],
#    'place_id': 'ChIJeU2cplic-RQRSPK29XNhKCs',
#    'plus_code': {'compound_code': '77CV+JW Port Fouad City, Egypt',
#     'global_code': '8G3J77CV+JW'},
#    'rating': 3.9,
#    'reference': 'ChIJeU2cplic-RQRSPK29XNhKCs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 583,
#    'vicinity': 'El-Shaheed Atef El-Sadat, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2628555, 'lng': 32.3103474},
#     'viewport': {'northeast': {'lat': 31.26415707989272,
#       'lng': 32.31178992989273},
#      'southwest': {'lat': 31.26145742010727, 'lng': 32.30909027010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'De La Poste Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107770440096684310689">A Google User</a>'],
#      'photo_reference': 'Aap_uEA0mXEe8Gbawe4So3hfvvU5qFh3ZHg0nyNjeBnB5CbwowXtZgcWNpe3FYq0NMfSDgbkl8gogK-T1ZRwAt2YCxBLW3PoqrmJQLe6C4Bhgjyxb1gC9RisxLJKW0YF-H_qfX5iDyo-NSMYRnn0xJcSEeb2hPDBO4tw756y6O85PiCXwUmb',
#      'width': 1200}],
#    'place_id': 'ChIJRwgEq1Sc-RQRkr3d8uoUmsc',
#    'plus_code': {'compound_code': '7876+44 Port Fouad City, Egypt',
#     'global_code': '8G3J7876+44'},
#    'rating': 3.3,
#    'reference': 'ChIJRwgEq1Sc-RQRkr3d8uoUmsc',
#    'scope': 'GOOGLE',
#    'types': ['bakery',
#     'cafe',
#     'lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 399,
#    'vicinity': 'El-Gomhoreya, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2710892, 'lng': 32.3151713},
#     'viewport': {'northeast': {'lat': 31.27238267989272,
#       'lng': 32.31648277989272},
#      'southwest': {'lat': 31.26968302010728, 'lng': 32.31378312010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Port Said Misr Travel Hotel',
#    'photos': [{'height': 1908,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109003141584980187960">mohamed gomaa</a>'],
#      'photo_reference': 'Aap_uEA4d0lIheRiT5EQYamiDMLHbP-ph83BsvXngk53K235tuFyQ6jDVD3rtxWm_0z8PG8q4U0GjfQFcNeLizfQMa3vhP1IpEJPE-AsBwBi5oeuPsuopXjkboE3a999GGfrwyE68DujG3NubHrqA153_gnJ6zpBiCVwuQzm0idiq2MN3d1Z',
#      'width': 4032}],
#    'place_id': 'ChIJLQLPQAGd-RQR2oe5rTUxfQ0',
#    'plus_code': {'compound_code': '78C8+C3 Port Fouad City, Egypt',
#     'global_code': '8G3J78C8+C3'},
#    'rating': 4.1,
#    'reference': 'ChIJLQLPQAGd-RQR2oe5rTUxfQ0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2048,
#    'vicinity': 'Tarh Al Bahr, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2677954, 'lng': 32.3145287},
#     'viewport': {'northeast': {'lat': 31.26917867989272,
#       'lng': 32.31582127989272},
#      'southwest': {'lat': 31.26647902010727, 'lng': 32.31312162010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Panorama Port Said Hotel',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100961422036321332808">Tamer Mohammad</a>'],
#      'photo_reference': 'Aap_uECGPNUf_y7szLwrCeJy9GQakwZfGqrYhq0kpKiji2zT8zYkgPAef3bJzHJ6L237C5Xv1usjmS-wnAaOEDNpPCCqaVWgNtcgmXKmEJkxUOqLFhEVd0UPAT0li7IjlqYWTNixCs7dqG83MCAqZRQkKFCWxEF5qoA23YicGVEkH51QA1OR',
#      'width': 4032}],
#    'place_id': 'ChIJ3bDhJwGd-RQRUV7qmXheQVM',
#    'plus_code': {'compound_code': '7897+4R Port Fouad City, Egypt',
#     'global_code': '8G3J7897+4R'},
#    'rating': 3.5,
#    'reference': 'ChIJ3bDhJwGd-RQRUV7qmXheQVM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 982,
#    'vicinity': 'El-Gomhoreya, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2727646, 'lng': 32.2907027},
#     'viewport': {'northeast': {'lat': 31.27404132989273,
#       'lng': 32.29204102989272},
#      'southwest': {'lat': 31.27134167010728, 'lng': 32.28934137010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Palma Hotel Port Said',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103230391246383473324">Heba Abo al-soud</a>'],
#      'photo_reference': 'Aap_uEDceS-1-_rKgYG8J3V-DLzEvdPoLh3f56SKecPN1QCBo2PMKPa54YkGCRRwfQHWqx3Qtel_2ICNY6fAd87OJH9EMekvt5jbetTDtydjnApgBy83r3UsEMyWki4P5LlIL7KbMZWpJKCU6I6Jkau0BjJ-m3JmYTvJhKr6NFxjN2JFE_GR',
#      'width': 4000}],
#    'place_id': 'ChIJn-PrJKud-RQR6GttV31B8Js',
#    'plus_code': {'compound_code': '77FR+47 Port Fouad City, Egypt',
#     'global_code': '8G3J77FR+47'},
#    'rating': 4.6,
#    'reference': 'ChIJn-PrJKud-RQR6GttV31B8Js',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'El-Shaheed Atef El-Sadat, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2652893, 'lng': 32.3018661},
#     'viewport': {'northeast': {'lat': 31.26662697989272,
#       'lng': 32.30321087989272},
#      'southwest': {'lat': 31.26392732010728, 'lng': 32.30051122010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Porto Said Hotel',
#    'photos': [{'height': 1868,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114787607392296888972">Mohamed Roshdi</a>'],
#      'photo_reference': 'Aap_uEClPj7qpJd0S6__DPbgqmBPoMxwjtPbHm2HQfgX8kmjVCRJWUuNZdrWLfoLC1cc-2-vnCqyTpRWJR1BSXEX3Uc_TA86BNiStJ3GwsfXayg_ydaafUTT1ZhKkjS3f8oHuK0sO0Y8KJ-dXpVmtHqO5uuTGOffIeGvlBv8i4jAD0sP5vRo',
#      'width': 4000}],
#    'place_id': 'ChIJodRzLu6d-RQRCUoHOGqzUek',
#    'plus_code': {'compound_code': '7882+4P El Sharq, Egypt',
#     'global_code': '8G3J7882+4P'},
#    'rating': 4.3,
#    'reference': 'ChIJodRzLu6d-RQRCUoHOGqzUek',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 52,
#    'vicinity': '23km, Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2601842, 'lng': 32.3075353},
#     'viewport': {'northeast': {'lat': 31.26153127989272,
#       'lng': 32.30889092989273},
#      'southwest': {'lat': 31.25883162010727, 'lng': 32.30619127010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'فندق يوتوبيا بورسعيد - Utopia Port Said Hotel',
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117570810739492346228">Leka&#39;a</a>'],
#      'photo_reference': 'Aap_uECkmW3eCKjlt5J8mToRfacAoxJqr8eDEjVFo4nOqicyEvXct5BovJO3-mez03f2pAnlZM94czKVnYAmUU4cR6_hyVp66bTfO3of5_GABlAghL7E3nTLTwdGADSheCb_8lhdG-K3slmfwr0zDyPO26QIy-PPUGFv6aHK-u4sIvlZ_FZB',
#      'width': 3968}],
#    'place_id': 'ChIJjVtmfZyd-RQRTr4iXlox0kg',
#    'plus_code': {'compound_code': '7865+32 El Sharq, Egypt',
#     'global_code': '8G3J7865+32'},
#    'rating': 3.8,
#    'reference': 'ChIJjVtmfZyd-RQRTr4iXlox0kg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 215,
#    'vicinity': 'ميدان المنشية - شارع الجيش وأحمد شوقي - بجوار عمر افندي بورسعيد'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2628607, 'lng': 32.3106957},
#     'viewport': {'northeast': {'lat': 31.26422772989272,
#       'lng': 32.31201277989272},
#      'southwest': {'lat': 31.26152807010727, 'lng': 32.30931312010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Hotel',
#    'photos': [{'height': 4618,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113328460233372744035">Khaled Elkilany</a>'],
#      'photo_reference': 'Aap_uECg1lxh0R7TxhoD-_UPWSJ0-Aj2GPJ2cjDZTrzlEvNdmNg7-15M4egNLCLyUEn0Oo2wZr-miBXrmcHWgK10W3QnQ7x5Bs3ck0qMSgMLmQkrO2Tb9WKk8jG8mo99QGvLw0FW1AcioteA7I9fGbigSOmnRltIew9sL1AgpKrzWksSihbn',
#      'width': 3464}],
#    'place_id': 'ChIJRd5bqlSc-RQRVdC-YGHPKpY',
#    'plus_code': {'compound_code': '7876+47 El Sharq, Egypt',
#     'global_code': '8G3J7876+47'},
#    'rating': 3.5,
#    'reference': 'ChIJRd5bqlSc-RQRVdC-YGHPKpY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 375,
#    'vicinity': 'El-Gomhoreya, El Sharq'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2713251, 'lng': 32.303946},
#     'viewport': {'northeast': {'lat': 31.27261637989272,
#       'lng': 32.30528892989273},
#      'southwest': {'lat': 31.26991672010728, 'lng': 32.30258927010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Marhaba Touristic Village',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101953953090055519918">Hassan Ghattass</a>'],
#      'photo_reference': 'Aap_uEA_turmHSYK3JMh3RiUN8bvMnGsrQBKONn1arPA6eVcgM2-ecl68Q8KqZfRz3z6a12AceR6XyvC1lbTSD0G5q3dO--r3uVrY7BPxBdezhm-YWVgXUSN03cuONrp3A8C0yoMgs9US8iDCog75400lbAnkt_nk3S6YXhIdKyYVNP4A42D',
#      'width': 3456}],
#    'place_id': 'ChIJdVw8wfic-RQRCvsvv9Trl7Y',
#    'plus_code': {'compound_code': '78C3+GH Port Fouad City, Egypt',
#     'global_code': '8G3J78C3+GH'},
#    'rating': 4.2,
#    'reference': 'ChIJdVw8wfic-RQRCvsvv9Trl7Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2902,
#    'vicinity': 'El-Shaheed Atef El-Sadat, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2596589, 'lng': 32.3037789},
#     'viewport': {'northeast': {'lat': 31.26108357989272,
#       'lng': 32.30518347989272},
#      'southwest': {'lat': 31.25838392010728, 'lng': 32.30248382010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel concord',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113610662059112933597">kimo Blanco</a>'],
#      'photo_reference': 'Aap_uEDSefxLYB63FW8xEMTrAqHjUIpHGiV_UDIp5k28r6dHbaTY0wVg0LoY8jLBUgAfKRjsjNV5WymSQRAvw-Sd4WRNVItWlWrToQ2RqNE0h_8sUSqKQqkc3eRf_sxuI0p_yFuEGuEewsVRYlACIJvWzVLl8w-WI1f2zuGuH3lYnEpiLanD',
#      'width': 4000}],
#    'place_id': 'ChIJLw9ZGd2d-RQRcF3rTpmwkik',
#    'plus_code': {'compound_code': '7853+VG Port Fouad City, Egypt',
#     'global_code': '8G3J7853+VG'},
#    'rating': 3.4,
#    'reference': 'ChIJLw9ZGd2d-RQRcF3rTpmwkik',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 180,
#    'vicinity': 'Port Said Customs Authority, Mostafa Kamel, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2615297, 'lng': 32.3059711},
#     'viewport': {'northeast': {'lat': 31.26291277989272,
#       'lng': 32.30734687989272},
#      'southwest': {'lat': 31.26021312010727, 'lng': 32.30464722010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Light City Hotel',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100663805180067850548">em bee</a>'],
#      'photo_reference': 'Aap_uEAFAX2dsgPF-e997kVvrXu3MZ3tFly56usu67bZgqd98Q5YOzI_ZnxugJegxhSh5KSZJp-jQBvLWKkCfckxzJJgj67Jb0o9zrK2qrkkyg51hBhZwjKjXTZDse2Qlpx2S79zy7cYCvEb9saZqvhMGS8XstmLd2L0FcPTsrAIi-5oRBtI',
#      'width': 1920}],
#    'place_id': 'ChIJnauqdlGc-RQRgSqm0hqkKE0',
#    'rating': 3.4,
#    'reference': 'ChIJnauqdlGc-RQRgSqm0hqkKE0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 453,
#    'vicinity': '7864+J99, Port Fouad City'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2631384, 'lng': 32.3113733},
#     'viewport': {'northeast': {'lat': 31.26443972989272,
#       'lng': 32.31268472989273},
#      'southwest': {'lat': 31.26174007010727, 'lng': 32.30998507010729}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'New Regent Hotel',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111149741898700371774">shokry mahsob</a>'],
#      'photo_reference': 'Aap_uED-HIpUnAs8ora8Xu_MSkMJ1kPplm26VLQ64qRNqC75e5Ylen-p_nyK67v8aaILe__jT7rmU2cShcdZuv3k_1DSOtez5310yrqPmj-lKXGekw8QrDInbnCjR7hs7-x6XH4gI2MnxPQGOh7gBdkSfCEMBG9Eza1ecv_X48B7ihnGNZGM',
#      'width': 3120}],
#    'place_id': 'ChIJE0qusVSc-RQRQutWEmh4oSA',
#    'plus_code': {'compound_code': '7876+7G El Sharq, Egypt',
#     'global_code': '8G3J7876+7G'},
#    'rating': 2.8,
#    'reference': 'ChIJE0qusVSc-RQRQutWEmh4oSA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 172,
#    'vicinity': 'El Sharq'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.271036, 'lng': 32.302322},
#     'viewport': {'northeast': {'lat': 31.27241722989272,
#       'lng': 32.30367482989272},
#      'southwest': {'lat': 31.26971757010728, 'lng': 32.30097517010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Palma Hotel Apartments',
#    'photos': [{'height': 2184,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114146990127806752569">A Google User</a>'],
#      'photo_reference': 'Aap_uEAM70BsHUN01cIx0q172JJgHY5uVI5ISU8f7j7rEMnX6n42HD1h60KgqBGljEKTtV7R9OGU-f6ncOaybiCJFwzVvJDeLDhi4z1NbjzWcsHMmIT6jyKGlReAXaJ0ns0IUH4vmiXvmh8gKpEctiWS1Ioj0lAPdJDvVQyD5QAhGC1yumT6',
#      'width': 4608}],
#    'place_id': 'ChIJSxc5iPic-RQRMwBb8sKu4Xc',
#    'plus_code': {'compound_code': '78C2+CW Qism El-Arab, Egypt',
#     'global_code': '8G3J78C2+CW'},
#    'rating': 5,
#    'reference': 'ChIJSxc5iPic-RQRMwBb8sKu4Xc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'El-Shaheed Atef El-Sadat, Qism El-Arab'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2692563, 'lng': 32.3058243},
#     'viewport': {'northeast': {'lat': 31.27061732989272,
#       'lng': 32.30710232989271},
#      'southwest': {'lat': 31.26791767010728, 'lng': 32.30440267010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Palace Hotel',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101602510138681559647">Ahmed Tourk</a>'],
#      'photo_reference': 'Aap_uEBOF2GsnBijeXC8TVkchmEHQJxZ2woU88LHMWsKW-PsYu38CQhUPdhEoAgwIyTCi8j5W2Oz-VMMgiFUhUE4MXscHG2wiKrWOFN8wI1_fflBsNoQTmNCBrBxFDq2uwN18aWtcSctwC9ZapeBPtBLcd7cDi7MKfn3w5CKpnzaW-rzgWne',
#      'width': 5333}],
#    'place_id': 'ChIJdZO2-VWc-RQRXZgDn8nUeMc',
#    'plus_code': {'compound_code': '7894+P8 El Sharq, Egypt',
#     'global_code': '8G3J7894+P8'},
#    'rating': 3.4,
#    'reference': 'ChIJdZO2-VWc-RQRXZgDn8nUeMc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 96,
#    'vicinity': '19 ش غاندى، حى الشرق، بور سعيد'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.2719657, 'lng': 32.2892244},
#     'viewport': {'northeast': {'lat': 31.27329212989272,
#       'lng': 32.29079657989272},
#      'southwest': {'lat': 31.27059247010727, 'lng': 32.28809692010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Port Said Club Hotel',
#    'place_id': 'ChIJVVWVyF-c-RQRXpkZUFOk2qw',
#    'rating': 3.5,
#    'reference': 'ChIJVVWVyF-c-RQRXpkZUFOk2qw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 30,
#    'vicinity': 'ادارة شمال التعليمية بورسعيد، ٢٣ يوليو ١٣٧شارع ٢٣ يوليو امام'}],
#  'status': 'OK'}

# %%
hotel_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 25                Coalinga  36.1397 -120.3602     79.34        64           0
# 34            San Patricio  28.0170  -97.5169     72.84        27           0
# 49                 Salalah  17.0151   54.0924     77.09        61           0
# 59          Puerto Peñasco  31.3167 -113.5333     74.91        73           0
# 60  Santa Cruz de Tenerife  28.4682  -16.2546     71.69        79           0
#
#     Wind Speed Country        Date  \
# 25        2.93      US  1635557418
# 34        7.76      US  1635557309
# 49        5.75      OM  1635557434
# 59        6.11      MX  1635557438
# 60        1.01      ES  1635557439
#
#                                      Hotel Name  \
# 25      Best Western Plus Coalinga Inn & Suites
# 34               Americas Best Value Inn Sinton
# 49                        Salalah Gardens Hotel
# 59  Peñasco Del Sol Hotel and Conference Center
# 60              Iberostar Heritage Grand Mencey
#
#                                         Hotel Address  Hotel Rating
# 25                           1786 Jayne Ave, Coalinga           4.5
# 34                                 8108 US-77, Sinton           3.4
# 49                           Al Rabat Street، Salalah           4.8
# 59  P.º las Glorias #1, Bella Vista, Centro, Puert...           4.4
# 60  Calle Dr. Jose Naveiras, 38, Santa Cruz de Ten...           4.6

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations,
    info_box_content = hotel_info)


# Display figure
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
